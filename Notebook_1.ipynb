# %% [markdown]
# this is the first notebook for the capstone project. I look forward to complete it successfully.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Hello Capstone Project Course!
